# %% [markdown]
# ## **13. 이상치 탐지**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %% [markdown]
# ### **데이터 탐색**

# %%
"""
    데이터셋 로딩
"""

def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S') #datetime 메서드 사용

path = './data/'
file = 'AirQualityUCI_refined.csv'

df = pd.read_csv(
    path + file,
    index_col=[0],
    parse_dates=[0], 
    date_parser=parser
)

df.head()
# Out:
# C:\Users\hj343\AppData\Local\Temp\ipykernel_13860\1655143481.py:11: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(
#                      CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0         1046.0    166.0
# 2004-03-10 19:00:00     2.0       1292.0          955.0    103.0
# 2004-03-10 20:00:00     2.2       1402.0          939.0    131.0
# 2004-03-10 21:00:00     2.2       1376.0          948.0    172.0
# 2004-03-10 22:00:00     1.6       1272.0          836.0    131.0
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH  \
# Datetime
# 2004-03-10 18:00:00        1056.0    113.0        1692.0       1268.0  48.9
# 2004-03-10 19:00:00        1174.0     92.0        1559.0        972.0  47.7
# 2004-03-10 20:00:00        1140.0    114.0        1555.0       1074.0  54.0
# 2004-03-10 21:00:00        1092.0    122.0        1584.0       1203.0  60.0
# 2004-03-10 22:00:00        1205.0    116.0        1490.0       1110.0  59.6
#
#                          AH  C6H6(GT)
# Datetime
# 2004-03-10 18:00:00  0.7578      11.9
# 2004-03-10 19:00:00  0.7255       9.4
# 2004-03-10 20:00:00  0.7502       9.0
# 2004-03-10 21:00:00  0.7867       9.2
# 2004-03-10 22:00:00  0.7888       6.5

# %%
# [+] 일산화탄소 변수 (CO(GT)) 시각화
df['CO(GT)'].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# [+] 결측 데이터 처리: 선형 보간
co = df['CO(GT)'].copy() # Series 복사 #.copy
co.interpolate(inplace=True) # 선형 보간

# %%
# 결측치 처리 결과 시각화
plt.plot(df['CO(GT)'], label='original', zorder=2)
plt.plot(co, label='linear interpolation', zorder=1)
plt.legend(loc='best')
plt.show()

# %%
# [+] 이상치 시각화: 박스플롯
plt.boxplot(co)
plt.xlabel('CO(GT)')
plt.ylabel('Concentration (${mg/m^3}$)')
plt.show()

# %%
# [+] 변수 간 상관관계 측정 #-1과 1의 상관관계
corr_matrix = df.corr()
corr_matrix
# Out:
#                  CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# CO(GT)         1.000000     0.877203       0.914973  0.792557     -0.701703
# PT08.S1(CO)    0.877203     1.000000       0.892964  0.713654     -0.771938
# PT08.S2(NMHC)  0.914973     0.892964       1.000000  0.704435     -0.796703
# NOx(GT)        0.792557     0.713654       0.704435  1.000000     -0.655707
# PT08.S3(NOx)  -0.701703    -0.771938      -0.796703 -0.655707      1.000000
# NO2(GT)        0.679262     0.641529       0.646245  0.763111     -0.652083
# PT08.S4(NO2)   0.639470     0.682881       0.777254  0.233731     -0.538468
# PT08.S5(O3)    0.851403     0.899324       0.880578  0.787046     -0.796569
# RH             0.040218     0.114606      -0.090380  0.221032     -0.056740
# AH             0.065809     0.135324       0.186933 -0.149323     -0.232017
# C6H6(GT)       0.845144     0.883795       0.981950  0.626638     -0.735744
#
#                 NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)        RH        AH  \
# CO(GT)         0.679262      0.639470     0.851403  0.040218  0.065809
# PT08.S1(CO)    0.641529      0.682881     0.899324  0.114606  0.135324
# PT08.S2(NMHC)  0.646245      0.777254     0.880578 -0.090380  0.186933
# NOx(GT)        0.763111      0.233731     0.787046  0.221032 -0.149323
# PT08.S3(NOx)  -0.652083     -0.538468    -0.796569 -0.056740 -0.232017
# NO2(GT)        1.000000      0.157360     0.708128 -0.091759 -0.335022
# PT08.S4(NO2)   0.157360      1.000000     0.591144 -0.032188  0.629641
# PT08.S5(O3)    0.708128      0.591144     1.000000  0.124956  0.070751
# RH            -0.091759     -0.032188     0.124956  1.000000  0.167971
# AH            -0.335022      0.629641     0.070751  0.167971  1.000000
# C6H6(GT)       0.544039      0.765731     0.865689 -0.061681  0.167972
#
#                C6H6(GT)
# CO(GT)         0.845144
# PT08.S1(CO)    0.883795
# PT08.S2(NMHC)  0.981950
# NOx(GT)        0.626638
# PT08.S3(NOx)  -0.735744
# NO2(GT)        0.544039
# PT08.S4(NO2)   0.765731
# PT08.S5(O3)    0.865689
# RH            -0.061681
# AH             0.167972
# C6H6(GT)       1.000000

# %%
# 일산화탄소와 가장 상관관계가 약한 변수 선택 # 절대값이 0에 가까울 수록 사이에 상관관계가 없다.
rh = df['RH'].copy().interpolate() # RH: 상대습도

# %%
# 산포도 시각화
plt.scatter(co, rh, s=12, c='black')
plt.xlabel('CO(GT)')
plt.ylabel('RH')
plt.show()

# %%
# 일산화탄소와 가장 상관관계가 강한 변수 선택
nmhc = df['PT08.S2(NMHC)'].copy().interpolate() # NMHC: 비메탄계 탄화수소

# %%
# 산포도 시각화
plt.scatter(co, nmhc, s=12, c='black') #두 사이의 양의 상관관계가 강함.
plt.xlabel('CO(GT)')
plt.ylabel("NMHC")
plt.show()

# %% [markdown]
# ### **사분위수 범위 기반 이상치 탐지**

# %%
# [+] Q1, Q2, Q3 계산
q1 = co.quantile(0.25) #하위 25%
q2 = co.quantile(0.5) #median(중앙값)
q3 = co.quantile(0.75) #하위 75%
print(q1, q2, q3)
# Out:
# 1.1 1.8 2.9

# %%
co
# Out:
# Datetime
# 2004-03-10 18:00:00    2.6
# 2004-03-10 19:00:00    2.0
# 2004-03-10 20:00:00    2.2
# 2004-03-10 21:00:00    2.2
# 2004-03-10 22:00:00    1.6
#                       ...
# 2005-04-04 10:00:00    3.1
# 2005-04-04 11:00:00    2.4
# 2005-04-04 12:00:00    2.4
# 2005-04-04 13:00:00    2.1
# 2005-04-04 14:00:00    2.2
# Name: CO(GT), Length: 9357, dtype: float64

# %%
# [+] IQR, 상한(upper_fence), 하한(lower_fence)
iqr = q3 - q1
upper_fence = q3 + 1.5*iqr
lower_fence = q1 - 1.5*iqr
print(iqr, upper_fence, lower_fence)
# Out:
# 1.7999999999999998 5.6 -1.5999999999999996

# %%
# [+] 이상치 선택
outliers = co.loc[(co > upper_fence) | (co < lower_fence)]
outliers
# Out:
# Datetime
# 2004-03-11 19:00:00    6.9
# 2004-03-11 20:00:00    6.1
# 2004-03-12 20:00:00    6.6
# 2004-03-14 20:00:00    5.9
# 2004-03-15 09:00:00    8.1
#                       ...
# 2005-03-23 19:00:00    6.2
# 2005-03-23 20:00:00    7.2
# 2005-03-24 19:00:00    5.9
# 2005-03-24 20:00:00    7.5
# 2005-03-25 19:00:00    5.7
# Name: CO(GT), Length: 224, dtype: float64

# %%
outliers.index
# Out:
# DatetimeIndex(['2004-03-11 19:00:00', '2004-03-11 20:00:00',
#                '2004-03-12 20:00:00', '2004-03-14 20:00:00',
#                '2004-03-15 09:00:00', '2004-03-15 10:00:00',
#                '2004-03-15 18:00:00', '2004-03-15 19:00:00',
#                '2004-03-15 20:00:00', '2004-03-17 09:00:00',
#                ...
#                '2005-03-15 21:00:00', '2005-03-21 09:00:00',
#                '2005-03-21 19:00:00', '2005-03-21 20:00:00',
#                '2005-03-22 20:00:00', '2005-03-23 19:00:00',
#                '2005-03-23 20:00:00', '2005-03-24 19:00:00',
#                '2005-03-24 20:00:00', '2005-03-25 19:00:00'],
#               dtype='datetime64[ns]', name='Datetime', length=224, freq=None)

# %%
# [+] 이상치 여부 마스킹
mask = co.index.isin(outliers.index)
mask[:50]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
# 정상 데이터 / 이상치 시각화
plt.plot(co[~mask], label='normal', color='blue', #~mask 반대연산자 ~ 
    marker='o', markersize=3, linestyle='None')
plt.plot(outliers, label='outliers', color='red',
    marker='x', markersize=3, linestyle='None')
plt.legend(loc='best')

# %%
co[mask]
# Out:
# Datetime
# 2004-03-11 19:00:00    6.9
# 2004-03-11 20:00:00    6.1
# 2004-03-12 20:00:00    6.6
# 2004-03-14 20:00:00    5.9
# 2004-03-15 09:00:00    8.1
#                       ...
# 2005-03-23 19:00:00    6.2
# 2005-03-23 20:00:00    7.2
# 2005-03-24 19:00:00    5.9
# 2005-03-24 20:00:00    7.5
# 2005-03-25 19:00:00    5.7
# Name: CO(GT), Length: 224, dtype: float64

# %%
# [+] 이상치 제거
co_refined = co.copy()
co_refined[mask] = np.nan
co_refined[mask]
# Out:
# Datetime
# 2004-03-11 19:00:00   NaN
# 2004-03-11 20:00:00   NaN
# 2004-03-12 20:00:00   NaN
# 2004-03-14 20:00:00   NaN
# 2004-03-15 09:00:00   NaN
#                        ..
# 2005-03-23 19:00:00   NaN
# 2005-03-23 20:00:00   NaN
# 2005-03-24 19:00:00   NaN
# 2005-03-24 20:00:00   NaN
# 2005-03-25 19:00:00   NaN
# Name: CO(GT), Length: 224, dtype: float64

# %%
# [+] 제거된 이상치에 대한 대치: 선형보간
co_refined.interpolate(inplace=True)
co_refined.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# ### **Z-점수 기반 이상치 탐지**

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hj343\anaconda3\envs\daen\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# 일산화탄소 변수 분포 시각화
import seaborn as sns
sns.distplot(co)
# Out:
# C:\Users\hj343\AppData\Local\Temp\ipykernel_13860\4145667950.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(co)
# <Axes: xlabel='CO(GT)', ylabel='Density'>

# %%
# [+] 평균, 표준편차
mean = np.mean(co)
std = np.std(co)
print(mean, std)
# Out:
# 2.126146200705354 1.4369815748596482

# %%
# [+] 데이터 포인트별 Z-점수 계산
outliers = []
thres = 3

for i in co:
    z_score = (i - mean) / std
    if (np.abs(z_score) > thres):
        print(z_score)
        outliers.append(i)
# Out:
# 3.322139881828975
# 3.1133689377552476
# 4.1572236581238835
# 4.087633343432642
# 3.0437786230640054
# 3.1133689377552476
# 3.8092720846676715
# 3.1829592524464903
# 3.1133689377552476
# 3.6005011405939444
# 3.530910825902702
# 3.0437786230640054
# 3.0437786230640054
# 3.1829592524464903
# 3.0437786230640054
# 3.6005011405939444
# 3.1829592524464903
# 3.7396817699764293
# 3.0437786230640054
# 3.1829592524464903
# 3.3917301965202173
# 4.087633343432642
# 3.878862399358914
# 3.2525495671377325
# 4.3659946021976115
# 3.2525495671377325
# 4.018043028741399
# 4.3659946021976115
# 4.087633343432642
# 4.3659946021976115
# 5.131488063801277
# 3.0437786230640054
# 3.1133689377552476
# 3.7396817699764293
# 3.2525495671377325
# 4.018043028741399
# 4.087633343432642
# 4.922717119727549
# 3.3917301965202173
# 3.786075313103924
# 4.180420429687631
# 4.574765546271338
# 4.1572236581238835
# 4.087633343432642
# 3.1133689377552476
# 3.2525495671377325
# 3.9484527140501564
# 5.618620266639974
# 3.1133689377552476
# 3.7396817699764293
# 3.530910825902702
# 4.296404287506369
# 4.505175231580095
# 3.322139881828975
# 3.0437786230640054
# 3.1133689377552476
# 3.6005011405939444
# 3.6005011405939444
# 5.618620266639974
# 6.801655616391094
# 6.523294357626126
# 4.296404287506369
# 3.2525495671377325
# 4.3659946021976115
# 3.878862399358914
# 5.549029951948731
# 3.878862399358914
# 4.1572236581238835
# 3.1133689377552476
# 3.2525495671377325
# 3.7396817699764293
# 3.878862399358914
# 5.061897749110035
# 3.9484527140501564
# 3.1133689377552476
# 3.322139881828975
# 5.409849322566247
# 3.322139881828975
# 3.670091455285187
# 4.992307434418793
# 3.670091455285187
# 3.1133689377552476
# 3.6005011405939444
# 3.7396817699764293
# 4.505175231580095
# 4.8531268050363074
# 4.505175231580095
# 3.1133689377552476
# 4.435584916888853
# 4.574765546271338
# 4.8531268050363074
# 3.530910825902702
# 3.1133689377552476
# 3.0437786230640054
# 3.322139881828975
# 4.018043028741399
# 3.1829592524464903
# 3.2525495671377325
# 3.1829592524464903
# 3.2525495671377325
# 4.505175231580095
# 4.574765546271338
# 3.2525495671377325
# 3.2525495671377325
# 3.1829592524464903
# 3.1829592524464903
# 4.3659946021976115
# 3.4613205112114596
# 3.1133689377552476
# 3.0437786230640054
# 3.4613205112114596
# 3.0437786230640054
# 3.0437786230640054
# 3.670091455285187
# 3.530910825902702
# 3.7396817699764293

# %%
outliers
# Out:
# [6.9,
#  6.6,
#  8.1,
#  8.0,
#  6.5,
#  6.6,
#  7.6,
#  6.7,
#  6.6,
#  7.3,
#  7.2,
#  6.5,
#  6.5,
#  6.7,
#  6.5,
#  7.3,
#  6.7,
#  7.5,
#  6.5,
#  6.7,
#  7.0,
#  8.0,
#  7.7,
#  6.8,
#  8.4,
#  6.8,
#  7.9,
#  8.4,
#  8.0,
#  8.4,
#  9.5,
#  6.5,
#  6.6,
#  7.5,
#  6.8,
#  7.9,
#  8.0,
#  9.2,
#  7.0,
#  7.566666666666666,
#  8.133333333333333,
#  8.7,
#  8.1,
#  8.0,
#  6.6,
#  6.8,
#  7.8,
#  10.2,
#  6.6,
#  7.5,
#  7.2,
#  8.3,
#  8.6,
#  6.9,
#  6.5,
#  6.6,
#  7.3,
#  7.3,
#  10.2,
#  11.9,
#  11.5,
#  8.3,
#  6.8,
#  8.4,
#  7.7,
#  10.1,
#  7.7,
#  8.1,
#  6.6,
#  6.8,
#  7.5,
#  7.7,
#  9.4,
#  7.8,
#  6.6,
#  6.9,
#  9.9,
#  6.9,
#  7.4,
#  9.3,
#  7.4,
#  6.6,
#  7.3,
#  7.5,
#  8.6,
#  9.1,
#  8.6,
#  6.6,
#  8.5,
#  8.7,
#  9.1,
#  7.2,
#  6.6,
#  6.5,
#  6.9,
#  7.9,
#  6.7,
#  6.8,
#  6.7,
#  6.8,
#  8.6,
#  8.7,
#  6.8,
#  6.8,
#  6.7,
#  6.7,
#  8.4,
#  7.1,
#  6.6,
#  6.5,
#  7.1,
#  6.5,
#  6.5,
#  7.4,
#  7.2,
#  7.5]

# %%
# [+] 이상치 선택
outliers = co.loc[np.abs((co-mean) / std) > 3]
outliers
# Out:
# Datetime
# 2004-03-11 19:00:00    6.9
# 2004-03-12 20:00:00    6.6
# 2004-03-15 09:00:00    8.1
# 2004-03-15 19:00:00    8.0
# 2004-03-15 20:00:00    6.5
#                       ...
# 2005-03-14 19:00:00    6.5
# 2005-03-14 20:00:00    6.5
# 2005-03-15 20:00:00    7.4
# 2005-03-23 20:00:00    7.2
# 2005-03-24 20:00:00    7.5
# Name: CO(GT), Length: 116, dtype: float64

# %%
# [+] 마스킹
mask = co.index.isin(outliers.index)
mask[:50]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
# 이상치 제거 전/후 분포 시각화
sns.distplot(co, axlabel='CO(GT)', label='original')
sns.distplot(co[~mask], label='outliers removed')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\hj343\AppData\Local\Temp\ipykernel_13860\802724061.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(co, axlabel='CO(GT)', label='original')
# C:\Users\hj343\AppData\Local\Temp\ipykernel_13860\802724061.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(co[~mask], label='outliers removed')

# %%
np.mean(co[~mask])
# Out:
# 2.0112827048235826

# %%
np.std(co[~mask])
# Out:
# 1.122652859110625

# %%
# 기타 이상치 제거 방법: Flooring, Capping
floor = co.quantile(0.1) #하위 10%
cap = co.quantile(0.9) #상위 10%

co.loc[co < floor] = floor
co.loc[co > cap] = cap

# %%
# 시각화
co.plot()
# Out:
# <Axes: xlabel='Datetime'>
